# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' #to get rid of tensorflow CUDA warnings

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, Activation, Dense
import h5py
import pickle

# %%
batch_size = 32
img_height = 180
img_width = 180

train_path = "data/train/"
train_labels = os.listdir(train_path)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
)

class_names = train_ds.class_names
# Out:
# Found 20 files belonging to 2 classes.
# Using 16 files for training.

# %%
Video_FILE = "flower.mp4"

# %%
def get_frame(filename,index):
    counter=0
    video=cv2.VideoCapture(filename)
    while video.isOpened():
        rete,frame=video.read()
        if rete:
            if counter==index:
                return cv2.resize(frame, (180, 180)) 
            counter +=1
        else:
            break
    video.release()
    return None

# %%
frame = get_frame(Video_FILE,150)
print('shape is', frame.shape)
print('pixel at (60,21)',frame[60,21,:])
print('pixel at (120,10)',frame[120,10,:])
# Out:
# shape is (180, 180, 3)
# pixel at (60,21) [185  85  77]
# pixel at (120,10) [175  67  69]

# %%
pickled_model = pickle.load(open('model.pkl', 'rb'))while

# %%
for i in range(10):
    frame = get_frame(Video_FILE,i)

    img_array = tf.keras.utils.img_to_array(frame)
    img_array = tf.expand_dims(frame, 0) # Create a batch

    predictions = pickled_model.predict(img_array)
    
    score = tf.nn.softmax(predictions[0])

    print(
        "This image most likely belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )
# Out:
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.

# %%
video=cv2.VideoCapture(Video_FILE)

while video.isOpened():
    rete,frame=video.read()
    frame = cv2.resize(frame, (180, 180)) 
    img_array = tf.keras.utils.img_to_array(frame)
    img_array = tf.expand_dims(frame, 0) # Create a batch

    predictions = pickled_model.predict(img_array)

    score = tf.nn.softmax(predictions[0])

    print(
        "This image most likely belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )
video.release()
# Out:
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.89 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 100.00 percent confidence.
# This image most likely belongs to 0 with a 100.00 percent confidence.
# This image most likely belongs to 0 with a 100.00 percent confidence.
# This image most likely belongs to 0 with a 100.00 percent confidence.
# This image most likely belongs to 0 with a 100.00 percent confidence.
# This image most likely belongs to 0 with a 100.00 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.99 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.97 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.98 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.84 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.74 percent confidence.
# This image most likely belongs to 0 with a 99.63 percent confidence.
# This image most likely belongs to 0 with a 99.36 percent confidence.
# This image most likely belongs to 0 with a 98.30 percent confidence.
# This image most likely belongs to 0 with a 97.24 percent confidence.
# This image most likely belongs to 0 with a 94.86 percent confidence.
# This image most likely belongs to 0 with a 95.53 percent confidence.
# This image most likely belongs to 0 with a 96.04 percent confidence.
# This image most likely belongs to 0 with a 97.19 percent confidence.
# This image most likely belongs to 0 with a 97.54 percent confidence.
# This image most likely belongs to 0 with a 97.96 percent confidence.
# This image most likely belongs to 0 with a 98.08 percent confidence.
# This image most likely belongs to 0 with a 98.06 percent confidence.
# This image most likely belongs to 0 with a 97.70 percent confidence.
# This image most likely belongs to 0 with a 97.35 percent confidence.
# This image most likely belongs to 0 with a 96.91 percent confidence.
# This image most likely belongs to 0 with a 96.81 percent confidence.
# This image most likely belongs to 0 with a 96.78 percent confidence.
# This image most likely belongs to 0 with a 96.75 percent confidence.
# This image most likely belongs to 0 with a 96.75 percent confidence.
# This image most likely belongs to 0 with a 96.73 percent confidence.
# This image most likely belongs to 0 with a 96.76 percent confidence.
# This image most likely belongs to 0 with a 96.81 percent confidence.
# This image most likely belongs to 0 with a 97.00 percent confidence.
# This image most likely belongs to 0 with a 97.07 percent confidence.
# This image most likely belongs to 0 with a 97.21 percent confidence.
# This image most likely belongs to 0 with a 97.41 percent confidence.
# This image most likely belongs to 0 with a 97.45 percent confidence.
# This image most likely belongs to 0 with a 97.54 percent confidence.
# This image most likely belongs to 0 with a 97.62 percent confidence.
# This image most likely belongs to 0 with a 97.77 percent confidence.
# This image most likely belongs to 0 with a 97.95 percent confidence.
# This image most likely belongs to 0 with a 98.01 percent confidence.
# This image most likely belongs to 0 with a 98.19 percent confidence.
# This image most likely belongs to 0 with a 98.22 percent confidence.
# This image most likely belongs to 0 with a 98.36 percent confidence.
# This image most likely belongs to 0 with a 98.44 percent confidence.
# This image most likely belongs to 0 with a 98.47 percent confidence.
# This image most likely belongs to 0 with a 98.56 percent confidence.
# This image most likely belongs to 0 with a 98.57 percent confidence.
# This image most likely belongs to 0 with a 98.64 percent confidence.
# This image most likely belongs to 0 with a 98.70 percent confidence.
# This image most likely belongs to 0 with a 98.73 percent confidence.
# This image most likely belongs to 0 with a 98.81 percent confidence.
# This image most likely belongs to 0 with a 98.80 percent confidence.
# This image most likely belongs to 0 with a 98.83 percent confidence.
# This image most likely belongs to 0 with a 98.87 percent confidence.
# This image most likely belongs to 0 with a 98.87 percent confidence.
# This image most likely belongs to 0 with a 98.90 percent confidence.
# This image most likely belongs to 0 with a 98.89 percent confidence.
# This image most likely belongs to 0 with a 98.90 percent confidence.
# This image most likely belongs to 0 with a 98.92 percent confidence.
# This image most likely belongs to 0 with a 98.93 percent confidence.
# This image most likely belongs to 0 with a 98.94 percent confidence.
# This image most likely belongs to 0 with a 98.96 percent confidence.
# This image most likely belongs to 0 with a 99.00 percent confidence.
# This image most likely belongs to 0 with a 98.98 percent confidence.
# This image most likely belongs to 0 with a 98.99 percent confidence.
# This image most likely belongs to 0 with a 99.07 percent confidence.
# This image most likely belongs to 0 with a 99.11 percent confidence.
# This image most likely belongs to 0 with a 99.14 percent confidence.
# This image most likely belongs to 0 with a 99.16 percent confidence.
# This image most likely belongs to 0 with a 99.16 percent confidence.
# This image most likely belongs to 0 with a 99.16 percent confidence.
# This image most likely belongs to 0 with a 99.17 percent confidence.
# This image most likely belongs to 0 with a 99.13 percent confidence.
# This image most likely belongs to 0 with a 99.13 percent confidence.
# This image most likely belongs to 0 with a 99.10 percent confidence.
# This image most likely belongs to 0 with a 99.07 percent confidence.
# This image most likely belongs to 0 with a 99.08 percent confidence.
# This image most likely belongs to 0 with a 99.05 percent confidence.
# This image most likely belongs to 0 with a 99.07 percent confidence.
# This image most likely belongs to 0 with a 99.06 percent confidence.
# This image most likely belongs to 0 with a 99.04 percent confidence.
# This image most likely belongs to 0 with a 99.05 percent confidence.
# This image most likely belongs to 0 with a 99.07 percent confidence.
# This image most likely belongs to 0 with a 99.16 percent confidence.
# This image most likely belongs to 0 with a 99.20 percent confidence.
# This image most likely belongs to 0 with a 99.24 percent confidence.
# This image most likely belongs to 0 with a 99.30 percent confidence.
# This image most likely belongs to 0 with a 99.31 percent confidence.
# This image most likely belongs to 0 with a 99.36 percent confidence.
# This image most likely belongs to 0 with a 99.38 percent confidence.
# This image most likely belongs to 0 with a 99.39 percent confidence.
# This image most likely belongs to 0 with a 99.38 percent confidence.
# This image most likely belongs to 0 with a 99.40 percent confidence.
# This image most likely belongs to 0 with a 99.42 percent confidence.
# This image most likely belongs to 0 with a 99.44 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.43 percent confidence.
# This image most likely belongs to 0 with a 99.43 percent confidence.
# This image most likely belongs to 0 with a 99.43 percent confidence.
# This image most likely belongs to 0 with a 99.46 percent confidence.
# This image most likely belongs to 0 with a 99.46 percent confidence.
# This image most likely belongs to 0 with a 99.46 percent confidence.
# This image most likely belongs to 0 with a 99.46 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.47 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.48 percent confidence.
# This image most likely belongs to 0 with a 99.44 percent confidence.
# This image most likely belongs to 0 with a 99.44 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.45 percent confidence.
# This image most likely belongs to 0 with a 99.42 percent confidence.
# This image most likely belongs to 0 with a 99.38 percent confidence.
# This image most likely belongs to 0 with a 99.30 percent confidence.
# This image most likely belongs to 0 with a 99.25 percent confidence.
# This image most likely belongs to 0 with a 99.19 percent confidence.
# This image most likely belongs to 0 with a 99.15 percent confidence.
# This image most likely belongs to 0 with a 99.02 percent confidence.
# This image most likely belongs to 0 with a 98.98 percent confidence.
# This image most likely belongs to 0 with a 98.94 percent confidence.
# This image most likely belongs to 0 with a 98.86 percent confidence.
# This image most likely belongs to 0 with a 98.83 percent confidence.
# This image most likely belongs to 0 with a 98.75 percent confidence.
# This image most likely belongs to 0 with a 98.69 percent confidence.
# This image most likely belongs to 0 with a 98.66 percent confidence.
# This image most likely belongs to 0 with a 98.62 percent confidence.
# This image most likely belongs to 0 with a 98.56 percent confidence.
# This image most likely belongs to 0 with a 98.53 percent confidence.
# This image most likely belongs to 0 with a 98.45 percent confidence.
# This image most likely belongs to 0 with a 98.44 percent confidence.
# This image most likely belongs to 0 with a 98.44 percent confidence.
# This image most likely belongs to 0 with a 98.42 percent confidence.
# This image most likely belongs to 0 with a 98.40 percent confidence.
# This image most likely belongs to 0 with a 98.39 percent confidence.
# This image most likely belongs to 0 with a 98.39 percent confidence.
# This image most likely belongs to 0 with a 98.39 percent confidence.
# This image most likely belongs to 0 with a 98.39 percent confidence.
# This image most likely belongs to 0 with a 98.39 percent confidence.
# This image most likely belongs to 0 with a 98.39 percent confidence.
# This image most likely belongs to 0 with a 96.44 percent confidence.
# This image most likely belongs to 0 with a 96.44 percent confidence.
# This image most likely belongs to 0 with a 96.44 percent confidence.
# This image most likely belongs to 0 with a 96.44 percent confidence.
# This image most likely belongs to 0 with a 96.44 percent confidence.
# This image most likely belongs to 0 with a 96.53 percent confidence.
# This image most likely belongs to 0 with a 96.85 percent confidence.
# This image most likely belongs to 0 with a 96.73 percent confidence.
# This image most likely belongs to 0 with a 96.04 percent confidence.
# This image most likely belongs to 0 with a 94.49 percent confidence.
# This image most likely belongs to 0 with a 91.87 percent confidence.
# This image most likely belongs to 0 with a 79.97 percent confidence.
# This image most likely belongs to 0 with a 64.93 percent confidence.
# This image most likely belongs to 1 with a 57.11 percent confidence.
# This image most likely belongs to 1 with a 81.31 percent confidence.
# This image most likely belongs to 1 with a 94.80 percent confidence.
# This image most likely belongs to 1 with a 98.87 percent confidence.
# This image most likely belongs to 1 with a 99.74 percent confidence.
# This image most likely belongs to 1 with a 99.95 percent confidence.
# This image most likely belongs to 1 with a 99.99 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 100.00 percent confidence.
# This image most likely belongs to 1 with a 99.48 percent confidence.
# This image most likely belongs to 1 with a 63.92 percent confidence.
# This image most likely belongs to 0 with a 90.45 percent confidence.
# This image most likely belongs to 0 with a 97.48 percent confidence.
# This image most likely belongs to 0 with a 98.99 percent confidence.
# This image most likely belongs to 0 with a 99.38 percent confidence.
# This image most likely belongs to 0 with a 99.42 percent confidence.
# This image most likely belongs to 0 with a 99.46 percent confidence.
# This image most likely belongs to 0 with a 99.51 percent confidence.
# This image most likely belongs to 0 with a 99.55 percent confidence.
# This image most likely belongs to 0 with a 99.55 percent confidence.
# This image most likely belongs to 0 with a 99.57 percent confidence.
# This image most likely belongs to 0 with a 99.59 percent confidence.
# This image most likely belongs to 0 with a 99.51 percent confidence.
# This image most likely belongs to 0 with a 99.52 percent confidence.
# This image most likely belongs to 0 with a 99.53 percent confidence.
# This image most likely belongs to 0 with a 99.53 percent confidence.
# This image most likely belongs to 0 with a 99.53 percent confidence.
# This image most likely belongs to 0 with a 99.53 percent confidence.
# This image most likely belongs to 0 with a 99.53 percent confidence.
# This image most likely belongs to 0 with a 99.54 percent confidence.
# This image most likely belongs to 0 with a 99.55 percent confidence.
# This image most likely belongs to 0 with a 99.56 percent confidence.
# This image most likely belongs to 0 with a 99.59 percent confidence.
# This image most likely belongs to 0 with a 99.60 percent confidence.
# This image most likely belongs to 0 with a 99.62 percent confidence.
# This image most likely belongs to 0 with a 99.62 percent confidence.
# This image most likely belongs to 0 with a 99.64 percent confidence.
# This image most likely belongs to 0 with a 99.66 percent confidence.
# This image most likely belongs to 0 with a 99.68 percent confidence.
# This image most likely belongs to 0 with a 99.70 percent confidence.
# This image most likely belongs to 0 with a 99.71 percent confidence.
# This image most likely belongs to 0 with a 99.72 percent confidence.
# This image most likely belongs to 0 with a 99.73 percent confidence.
# This image most likely belongs to 0 with a 99.72 percent confidence.
# This image most likely belongs to 0 with a 99.74 percent confidence.
# This image most likely belongs to 0 with a 99.75 percent confidence.
# This image most likely belongs to 0 with a 99.76 percent confidence.
# This image most likely belongs to 0 with a 99.76 percent confidence.
# This image most likely belongs to 0 with a 99.76 percent confidence.
# This image most likely belongs to 0 with a 99.76 percent confidence.
# This image most likely belongs to 0 with a 99.77 percent confidence.
# This image most likely belongs to 0 with a 99.77 percent confidence.
# This image most likely belongs to 0 with a 99.77 percent confidence.
# This image most likely belongs to 0 with a 99.77 percent confidence.
# This image most likely belongs to 0 with a 99.77 percent confidence.
# This image most likely belongs to 0 with a 99.77 percent confidence.
# This image most likely belongs to 0 with a 99.77 percent confidence.
# This image most likely belongs to 0 with a 99.78 percent confidence.
# This image most likely belongs to 0 with a 99.79 percent confidence.
# This image most likely belongs to 0 with a 99.79 percent confidence.
# This image most likely belongs to 0 with a 99.79 percent confidence.
# This image most likely belongs to 0 with a 99.80 percent confidence.
# This image most likely belongs to 0 with a 99.81 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.82 percent confidence.
# This image most likely belongs to 0 with a 99.81 percent confidence.
# This image most likely belongs to 0 with a 99.83 percent confidence.
# This image most likely belongs to 0 with a 99.85 percent confidence.
# This image most likely belongs to 0 with a 99.86 percent confidence.
# This image most likely belongs to 0 with a 99.85 percent confidence.
# This image most likely belongs to 0 with a 99.86 percent confidence.
# This image most likely belongs to 0 with a 99.86 percent confidence.
# This image most likely belongs to 0 with a 99.87 percent confidence.
# ...
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.90 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.91 percent confidence.
# This image most likely belongs to 0 with a 99.84 percent confidence.
# This image most likely belongs to 0 with a 99.67 percent confidence.
# This image most likely belongs to 0 with a 99.35 percent confidence.
# This image most likely belongs to 0 with a 98.61 percent confidence.
# This image most likely belongs to 0 with a 97.08 percent confidence.
# This image most likely belongs to 0 with a 94.44 percent confidence.
# This image most likely belongs to 0 with a 89.59 percent confidence.
# This image most likely belongs to 0 with a 82.97 percent confidence.
# This image most likely belongs to 0 with a 72.89 percent confidence.
# This image most likely belongs to 0 with a 59.98 percent confidence.
# This image most likely belongs to 0 with a 56.43 percent confidence.
# This image most likely belongs to 1 with a 52.14 percent confidence.
# This image most likely belongs to 1 with a 54.15 percent confidence.
# This image most likely belongs to 1 with a 54.13 percent confidence.
# This image most likely belongs to 1 with a 54.12 percent confidence.
# This image most likely belongs to 1 with a 54.12 percent confidence.
# This image most likely belongs to 1 with a 53.92 percent confidence.
# This image most likely belongs to 1 with a 53.89 percent confidence.
# This image most likely belongs to 1 with a 53.90 percent confidence.
# This image most likely belongs to 1 with a 53.90 percent confidence.
# This image most likely belongs to 1 with a 53.90 percent confidence.
# This image most likely belongs to 1 with a 53.90 percent confidence.
# This image most likely belongs to 1 with a 53.90 percent confidence.
# This image most likely belongs to 1 with a 53.90 percent confidence.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_615439/929605691.py in <module>
#       4     while video.isOpened():
#       5         rete,frame=video.read()
# ----> 6         frame = cv2.resize(frame, (180, 180))
#       7
#       8         img_array = tf.keras.utils.img_to_array(frame)
#
# error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
video=cv2.VideoCapture(filename)
while video.isOpened():
    rete,frame=video.read()
